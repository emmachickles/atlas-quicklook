# %% [markdown]
# ## Pick a source and view the raw light curve

# %%
# Set this to a valid ATLAS source ID (directory/file under /data2/ATLAS/WDs)
source_id = 840253451736047616

from atlas_ql.utils.io import read_lightcurve
lc = read_lightcurve(source_id)

# %%
from atlas_ql.utils.plotting import plot_lightcurve
fig = plot_lightcurve(lc)
print(f'R.A., Dec :   {lc["ra"]} {lc["dec"]}')
# Out:
# R.A., Dec :   174.38412 52.82006

# %%
from atlas_ql.utils.io import read_bin_lightcurve
from atlas_ql.utils.plotting import plot_binned_phase_folded
binned_lc = read_bin_lightcurve(source_id, num_bins=50) #, period=71.22997607/1440)
fig_binned = plot_binned_phase_folded(binned_lc)
# from atlas_ql.utils.paths import plots_path
# from atlas_ql.utils.bls import get_period
# from atlas_ql.utils.plotting import plot_phase_folded
# period = get_period(source_id)
# fig_binned.savefig(plots_path(f"{lc['ra']}_{lc['dec']}_{period}.png"))
# fig_folded = plot_phase_folded(lc, period)
# import matplotlib.pyplot as plt
# plt.ylim(-200, 100)
# Out:
# Period: 68.40625 min
