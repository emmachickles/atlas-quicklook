# %% [markdown]
# ## Pick a source and view the raw light curve

# %%
# Set this to a valid ATLAS source ID (directory/file under /data2/ATLAS/WDs)
source_id = 6027934755393713152

# %%
from atlas_ql.utils.io import read_lightcurve
lc = read_lightcurve(source_id)

# %%
from atlas_ql.utils.plotting import plot_lightcurve
fig = plot_lightcurve(lc)

# %%
from atlas_ql.utils.io import read_bin_lightcurve
binned_lc = read_bin_lightcurve(source_id)
# Out:
# /home/echickle/projects/atlas-quicklook/atlas_ql/utils/timeseries.py:125: RuntimeWarning: divide by zero encountered in divide
#   weights = 1.0 / (bin_flux_err**2)
# /home/echickle/projects/atlas-quicklook/atlas_ql/utils/timeseries.py:127: RuntimeWarning: invalid value encountered in multiply
#   weighted_mean = np.sum(bin_flux * weights) / np.sum(weights)

# %%
from atlas_ql.utils.plotting import plot_binned_phase_folded
fig_binned = plot_binned_phase_folded(binned_lc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from atlas_ql.utils.plotting import plot_binned_phase_folded
# ----> 2 fig_binned = plot_binned_phase_folded(binned_lc)
#
# NameError: name 'binned_lc' is not defined
